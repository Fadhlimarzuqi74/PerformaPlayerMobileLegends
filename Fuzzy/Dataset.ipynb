# %%
import requests
import json
import pandas as pd
from requests import get
import random
from itertools import product
import numpy as np

jungler_list  = ['Fredrinn', 'Baxia', 'Ling', 'Barats', 'Akai']
midlane_list  = ['Luo_Yi', 'Valentina', 'Novaria', 'Faramis', 'Pharsa']
roamer_list   = ['Ruby', 'Minotaur', 'Chip', 'Edith', 'Franco']
explane_list  = ['Cici', 'Terizla', 'Yu_Zhong', 'Xborg', 'Masha']
goldlane_list = ['Roger', 'Claude', 'Karrie', 'Natan', 'Moskov']

# %%
jungler_list = ['Fredrinn', 'Baxia', 'Ling', 'Barats', 'Akai']
player_name  = appendplayername(jungler_list)
print(player_name)
# Out:
# ['1rrad', '1rrad', '1rrad', 'Reyy', 'Reyy', 'Reyy', 'Reyy', 'Super Kenn', 'Anavel', 'Anavel', 'Reyy', 'Reyy', 'Reyy', 'Reyy', 'Reyy', 'Reyy', 'Anavel', 'Reyy', 'Kairi', 'Kairi', 'Anavel', 'Anavel', 'Anavel', '1rrad', 'Reyy', 'Reyy', 'Gugunnn', 'Gugunnn', 'Gugunnn', 'Kairi', 'Kairi', 'Kairi', 'Anavel', 'Super Kenn', 'Super Kenn', 'Super Kenn', 'Kairi', 'Anavel', 'Kairi', 'Reyy', 'Anavel', 'Reyy', 'Anavel', 'Kairi', 'Luke', 'Reyy', 'Reyy', 'Reyy', 'Super Kenn', 'Super Kenn', 'Fluffy', 'Luke', 'Lutpiii', '1rrad', 'Anavel', 'Kairi', 'Anavel']

# %%
midlane_list = ['Luo_Yi', 'Valentina', 'Novaria', 'Faramis', 'Pharsa']
player_name  = appendplayername(midlane_list)
print(player_name)
# Out:
# ['Clayyy', 'Aboy', 'Clayyy', 'Clayyy', 'Clawkun', 'Clawkun', 'Clawkun', 'Aboy', 'Sanz', 'Aboy', 'Moreno', 'Clawkun', 'Aboy', 'Aboy', 'Aboy', 'Aboy', 'Clayyy', 'Moreno', 'Clawkun', 'Clawkun', 'Moreno', 'Sanz', 'Clawkun', 'Clawkun', 'Clawkun', 'Clawkun', 'Clawkun', 'Sanz', 'Clawkun', 'Yehezkiel', 'Yehezkiel', 'Aboy', 'Aboy', 'Aboy', 'Clawkun', 'Clawkun', 'Moreno', 'Clawkun', 'Clawkun', 'Clawkun', 'Aboy', 'Aboy', 'Sanz', 'Aboy', 'Aboy', 'Aboy', 'Aboy', 'Clawkun', 'Clawkun', 'Sanz', 'Sanz', 'Moreno', 'Sanz', 'Sanz', 'Sanz']

# %%
roamer_list = ['Ruby', 'Minotaur', 'Chip', 'Edith', 'Franco']
player_name = appendplayername(roamer_list)
print(player_name)
# Out:
# ['Luke', 'Luke', 'Baloyskie', 'Baloyskie', 'Luke', 'Kiboy', 'Luke', 'Kiboy', 'Fluffy', 'Dreams', 'Baloyskie', 'Baloyskie', 'Kiboy', 'Dreams', 'Kiboy', 'Vyn', 'Vyn', 'Dreams', 'Dreams', 'Kyy', 'Baloyskie', 'Dreams', 'Dreams', 'Dreams', 'Vyn', 'Kiboy', 'Kiboy', 'Kyy', 'Kyy', 'Kyy', 'Baloyskie', 'Dreams', 'Dreams', 'Kiboy', 'Dreams', 'Kyy', 'Dreams', 'Dreams', 'Kiboy', 'Baloyskie', 'Kiboy', 'Baloyskie', 'Baloyskie', 'Kyy', 'Dreams', 'Dreams']

# %%
explane_list = ['Cici', 'Terizla', 'Yu_Zhong', 'Xborg', 'Masha']
player_name = appendplayername(explane_list)
print(player_name)
# Out:
# ['Aran', 'Aran', 'Lutpiii', 'Lutpiii', 'Xorizo', 'Xorizo', 'Xorizo', 'Lutpiii', 'Cw', 'Lutpiii', 'Fluffy', 'Fluffy', 'Xorizo', 'Fluffy', 'Fluffy', 'Fluffy', 'Fluffy', 'Fluffy', 'Lutpiii', 'Luke', 'Donn', 'Fluffy', 'Fluffy', 'Fluffy', 'Fluffy', 'Luke', 'Fluffy', 'Luke', 'Luke', 'Lutpiii', 'Fluffy', 'Fluffy', 'Fluffy', 'Luke', 'Luke', 'Luke', 'Luke', 'Fluffy', 'Lutpiii']

# %%
goldlane_list = ['Roger', 'Claude', 'Karrie', 'Natan', 'Moskov']
player_name = appendplayername(goldlane_list)
print(player_name)
# Out:
# ['Skylar', 'Skylar', 'Skylar', 'Skylar', 'Branz', 'Branz', 'Kabuki', 'Cw', 'Super Kenn', 'Emann', 'Emann', 'Cw', 'Cw', 'Branz', 'Branz', 'Branz', 'Branz', 'Caderaa', 'Branz', 'Cw', 'Cw', 'Branz', 'Cw', 'Kabuki', 'Branz', 'Caderaa', 'Caderaa', 'Cw', 'Branz', 'Branz', 'Caderaa', 'Branz', 'Branz', 'Cw', 'Caderaa', 'Caderaa', 'Caderaa', 'Caderaa', 'Branz', 'Cw', 'Cw', 'Skylar', 'Caderaa', 'Caderaa', 'Kabuki', 'Cw', 'Emann', 'Branz', 'Branz', 'Branz', 'Caderaa', 'Caderaa', 'Cw', 'Caderaa', 'Emann', 'Emann', 'Emann', 'Cw', 'Caderaa', 'Branz', 'Caderaa', 'Caderaa', 'Emann', 'Branz']
