# %%
import requests
import json
import pandas as pd
from requests import get
import random
from itertools import product
import numpy as np

jungler_list = ['medusa', 'tb', 'bs', 'morph', 'mk'  ]
midlane_list = ['ember', 'bat', 'storm', 'void', 'pango']
explane_list = ['doom', 'beast', 'sb', 'timber', 'underlord']
goldlane_list = ['techies', 'ench', 'undying', 'sky', 'mirana']
roamer_list = ['rubick', 'pugna', 'silencer', 'cm', 'disruptor']
